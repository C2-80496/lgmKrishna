# %% [markdown]
# LetsGrowMore- Virtual Internship Program (VIP)- Data Science
#
# Author : Krishna Vyas N.
#
# Task 4 :- Image to Pencil Sketch with Python

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/lgm_task.jfif")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F9E6C1165D0>

# %%
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F9E6C023FD0>

# %%
inverted_image = 255 - grey_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F9E6C032190>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F9E6C032A90>

# %%
def pencil_sketch(a, b):
  return cv2.divide(a, 255 - b, scale=256)
pencil_sketch=pencil_sketch(grey_image,blurred)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7F9E6AFBD750>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F9E6C038E50>
# <PIL.Image.Image image mode=L size=300x168 at 0x7F9E6C038DD0>
